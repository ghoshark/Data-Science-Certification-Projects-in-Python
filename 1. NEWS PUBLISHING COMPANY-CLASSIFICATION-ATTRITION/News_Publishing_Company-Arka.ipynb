# %%
# News Publishing Company

# %%
#Importing the required modules
import pandas as pd
import warnings
warnings.filterwarnings("ignore")
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import scipy.stats as stats
from sklearn.preprocessing import Imputer,StandardScaler,LabelEncoder
from sklearn.linear_model import LogisticRegression
import datetime
from sklearn import metrics
from sklearn.metrics import roc_auc_score,average_precision_score,accuracy_score,confusion_matrix,f1_score
from sklearn.model_selection import cross_val_score, train_test_split
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier, AdaBoostClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.neural_network import MLPClassifier
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis,QuadraticDiscriminantAnalysis
from sklearn.gaussian_process import GaussianProcessClassifier
import xgboost
# %matplotlib inline

# %%
#Importing Data
data1= pd.read_csv('Data/complaints.txt',sep=';',encoding='utf-8')
data2= pd.read_csv('Data/credit.txt',sep=';',encoding='utf-8')
data3= pd.read_csv('Data/customers.txt',sep=';',encoding='utf-8')
data4= pd.read_csv('Data/delivery.txt',sep=';',encoding='utf-8')
data5= pd.read_csv('Data/formula.txt',sep=';',encoding='utf-8')
data6= pd.read_csv('Data/subscriptions.txt',delim_whitespace=True,encoding='utf-8')

# %%
data1.head()
# Out:
#    ComplaintID  CustomerID  ProductID ComplaintDate  ComplaintType  \
# 0       181932        3464        8.0    14/10/2010              7
# 1       168698        3464        8.0    19/07/2010              1
# 2       163694        4107        8.0    11/06/2010              1
# 3       111664        4870        8.0    25/04/2009              1
# 4       139482        4870        8.0    05/12/2009              1
#
#    SolutionType  FeedbackType
# 0           2.0           NaN
# 1           2.0           3.0
# 2           2.0           3.0
# 3           3.0           3.0
# 4           3.0           3.0

# %%
data1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4125 entries, 0 to 4124
# Data columns (total 7 columns):
# ComplaintID      4125 non-null int64
# CustomerID       4125 non-null int64
# ProductID        3711 non-null float64
# ComplaintDate    4125 non-null object
# ComplaintType    4125 non-null int64
# SolutionType     3033 non-null float64
# FeedbackType     1623 non-null float64
# dtypes: float64(3), int64(3), object(1)
# memory usage: 225.7+ KB

# %%
data1.describe()
# Out:
#          ComplaintID    CustomerID    ProductID  ComplaintType  SolutionType  \
# count    4125.000000  4.125000e+03  3711.000000    4125.000000   3033.000000
# mean   116667.705939  5.490283e+05     5.818647       2.332848      1.721728
# std     44447.131851  3.192640e+05     2.305329       2.748423      0.770314
# min     37653.000000  3.464000e+03     1.000000       1.000000      1.000000
# 25%     80230.000000  2.304690e+05     4.000000       1.000000      1.000000
# 50%    112595.000000  6.572770e+05     7.000000       1.000000      2.000000
# 75%    153540.000000  7.781450e+05     8.000000       1.000000      2.000000
# max    202605.000000  1.167188e+06     8.000000       9.000000      4.000000
#
#        FeedbackType
# count   1623.000000
# mean       3.350585
# std        1.110292
# min        1.000000
# 25%        3.000000
# 50%        3.000000
# 75%        4.000000
# max        6.000000

# %%
data2.head()
# Out:
#    SubscriptionID ActionType ProcessingDate CreditSource  Amount  \
# 0         1002057         EN     18/05/2009          COM  1.0400
# 1         1002089         EN     06/10/2010          COM  0.8783
# 2         1002089         EN     22/12/2010          COM  0.8783
# 3         1002089         EN     23/12/2010          COM  0.8783
# 4         1002089         EN     24/12/2010          COM  0.8783
#
#    NbrNewspapers
# 0            1.0
# 1            1.0
# 2            1.0
# 3            1.0
# 4            1.0

# %%
data2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1940 entries, 0 to 1939
# Data columns (total 6 columns):
# SubscriptionID    1940 non-null int64
# ActionType        1940 non-null object
# ProcessingDate    1902 non-null object
# CreditSource      1940 non-null object
# Amount            1937 non-null float64
# NbrNewspapers     1408 non-null float64
# dtypes: float64(2), int64(1), object(3)
# memory usage: 91.0+ KB

# %%
data2.describe()
# Out:
#        SubscriptionID       Amount  NbrNewspapers
# count    1.940000e+03  1937.000000    1408.000000
# mean     4.860147e+05     6.297127       0.752841
# std      3.188891e+05    24.909583       1.667872
# min      5.933700e+04     0.000000       0.000000
# 25%      2.320825e+05     0.819100       0.000000
# 50%      4.131360e+05     1.000000       1.000000
# 75%      6.824305e+05     2.100000       1.000000
# max      1.354916e+06   263.486700      40.000000

# %%
data3.head()
# Out:
#    CustomerID Gender         DOB  District   ZIP  StreeID
# 0      908289      F  24/01/1957         5  3660    42555
# 1       55837      M  31/01/1948         1  2620    24910
# 2      493436      M  11/07/1977         5  3570    39586
# 3      913684      F  01/01/1900         5  3500    37484
# 4       36632      M  18/08/1952         5  3910    46296

# %%
data3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2356 entries, 0 to 2355
# Data columns (total 6 columns):
# CustomerID    2356 non-null int64
# Gender        2257 non-null object
# DOB           2356 non-null object
# District      2356 non-null int64
# ZIP           2356 non-null int64
# StreeID       2356 non-null int64
# dtypes: int64(4), object(2)
# memory usage: 110.5+ KB

# %%
data3.describe()
# Out:
#          CustomerID     District          ZIP        StreeID
# count  2.356000e+03  2356.000000  2356.000000    2356.000000
# mean   5.349043e+05     3.455008  3432.750424   36592.521647
# std    3.821129e+05     2.045992  1272.641443   17942.070858
# min    3.407000e+03     1.000000  1070.000000       0.000000
# 25%    1.308502e+05     1.000000  2640.000000   25083.000000
# 50%    6.165090e+05     5.000000  3530.000000   38524.500000
# 75%    8.522835e+05     5.000000  3700.000000   43773.500000
# max    1.167808e+06     8.000000  9800.000000  146620.000000

# %%
data4.head()
# Out:
#    SubscriptionID DeliveryType DeliveryClass DeliveryContext   StartDate  \
# 0         1000024           MD           NOR             NaN  18/01/2010
# 1         1000082           MD           ABN             NaN  12/02/2010
# 2         1000082           MD           NOR             NaN  15/01/2010
# 3         1000082           MD           NOR             NaN  14/02/2010
# 4         1000082           MD           ABN             NaN  14/01/2010
#
#       EndDate
# 0  17/04/2010
# 1  13/02/2010
# 2  11/02/2010
# 3  12/03/2010
# 4  14/01/2010

# %%
data4.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 26494 entries, 0 to 26493
# Data columns (total 6 columns):
# SubscriptionID     26494 non-null int64
# DeliveryType       26494 non-null object
# DeliveryClass      23106 non-null object
# DeliveryContext    11346 non-null object
# StartDate          26494 non-null object
# EndDate            26494 non-null object
# dtypes: int64(1), object(5)
# memory usage: 1.2+ MB

# %%
data4.describe()
# Out:
#        SubscriptionID
# count    2.649400e+04
# mean     6.709016e+05
# std      3.549329e+05
# min      5.382000e+04
# 25%      3.520410e+05
# 50%      6.888250e+05
# 75%      9.728482e+05
# max      1.361402e+06

# %%
data5.head()
# Out:
#    FormulaID  FormulaCode FormulaType  Duration
# 0      10011         2051         CAM        12
# 1      10013         2051         CAM        12
# 2      10014         2051         CAM         6
# 3      10017            3         CAM         3
# 4      10019           71         CAM         3

# %%
data5.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 997 entries, 0 to 996
# Data columns (total 4 columns):
# FormulaID      997 non-null int64
# FormulaCode    997 non-null int64
# FormulaType    997 non-null object
# Duration       997 non-null int64
# dtypes: int64(3), object(1)
# memory usage: 31.2+ KB

# %%
data5.describe()
# Out:
#           FormulaID  FormulaCode    Duration
# count    997.000000   997.000000  997.000000
# mean    6704.903711   973.668004    5.764293
# std     4544.819045  1514.764332    4.046865
# min       23.000000     1.000000    0.000000
# 25%     2551.000000     8.000000    3.000000
# 50%     6004.000000    82.000000    3.000000
# 75%     9585.000000  2046.000000   12.000000
# max    17444.000000  9000.000000   24.000000

# %%
data6.head()
# Out:
#          SubscriptionID  CustomerID  ProductID  \
# 1000024         1150045         8.0  1111110.0
# 1000082         1150046         8.0  1111110.0
# 100012            89085         8.0  1111110.0
# 100013            89085         8.0  1111110.0
# 100016            89087         8.0  1111110.0
#
#                                     Pattern   StartDate     EndDate  \
# 1000024  =VLOOKUP(D2;$E$15462:$F$15473;2;0)  18/01/2010  17/04/2010
# 1000082                          14/01/2010  12/03/2010          50
# 100012                            1/01/2008  30/12/2008         304
# 100013                            2/01/2007  31/12/2007         304
# 100016                            1/01/2008  30/12/2008         304
#
#         NbrNewspapers    NbrStart RenewalDate PaymentType     ...      \
# 1000024            76          25  17/03/2010          BT     ...
# 1000082            25   3/03/2010          BT        Paid     ...
# 100012             10  21/11/2008          BT        Paid     ...
# 100013             25   1/12/2007          BT        Paid     ...
# 100016             10  21/11/2008          BT        Paid     ...
#
#         PaymentDate FormulaID GrossFormulaPrice NetFormulaPrice  \
# 1000024  27/01/2010      8552                79              79
# 1000082       10017   519.737              29.6           0.592
# 100012          875       249               249        0.811842
# 100013          874       235               235        0.773026
# 100016          875       249               249        0.811842
#
#         NetNewspaperPrice ProductDiscount FormulaDiscount TotalDiscount  \
# 1000024         1.039.474               0               0             0
# 1000082                 0         223.737         223.737          29.6
# 100012                  0               0               0         246.8
# 100013                  0               0               0           235
# 100016                  0               0               0         246.8
#
#         TotalPrice TotalCredit
# 1000024         79         0.0
# 1000082          0         NaN
# 100012        -2.2         NaN
# 100013           0         NaN
# 100016        -2.2         NaN
#
# [5 rows x 21 columns]

# %%
data6.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 15471 entries, 1000024 to 100
# Data columns (total 21 columns):
# SubscriptionID       15471 non-null int64
# CustomerID           15459 non-null float64
# ProductID            15459 non-null float64
# Pattern              15459 non-null object
# StartDate            15459 non-null object
# EndDate              15459 non-null object
# NbrNewspapers        15459 non-null object
# NbrStart             15459 non-null object
# RenewalDate          15459 non-null object
# PaymentType          15459 non-null object
# PaymentStatus        15453 non-null object
# PaymentDate          15138 non-null object
# FormulaID            15138 non-null object
# GrossFormulaPrice    15138 non-null object
# NetFormulaPrice      15138 non-null object
# NetNewspaperPrice    15138 non-null object
# ProductDiscount      15138 non-null object
# FormulaDiscount      15138 non-null object
# TotalDiscount        15138 non-null object
# TotalPrice           10595 non-null object
# TotalCredit          1 non-null float64
# dtypes: float64(3), int64(1), object(17)
# memory usage: 2.6+ MB

# %%
data6.describe()
# Out:
#        SubscriptionID    CustomerID     ProductID  TotalCredit
# count    1.547100e+04  15459.000000  1.545900e+04          1.0
# mean     4.890274e+05      6.209522  1.082186e+06          0.0
# std      3.463220e+05      2.394066  1.757144e+05          NaN
# min      1.000000e+00      1.000000  1.000000e+01          0.0
# 25%      1.276830e+05      4.000000  1.111110e+06          0.0
# 50%      5.051710e+05      8.000000  1.111110e+06          0.0
# 75%      7.713630e+05      8.000000  1.111110e+06          0.0
# max      1.167808e+06      8.000000  1.111110e+06          0.0

# %%
#Exploring different data sets with visualizations

# %%
plt.figure(figsize=(10,5))
data1.groupby("ProductID").ComplaintID.count().sort_values(ascending=False).plot.bar()
plt.grid()
plt.show()

# %%
plt.figure(figsize=(10,5))
data1.groupby("ComplaintType").ProductID.count().sort_values(ascending=False).plot.bar()
plt.grid()
plt.show()

# %%
plt.figure(figsize=(10,5))
data3.groupby("District").CustomerID.count().sort_values(ascending=False).plot.bar()
plt.grid()
plt.show()

# %%
plt.figure(figsize=(10,5))
data5.groupby("Duration").FormulaID.count().sort_values(ascending=False).plot.bar()
plt.grid()
plt.show()

# %%
plt.figure(figsize=(10,5))
data3.groupby("Gender").CustomerID.count().sort_values(ascending=False).plot.bar()
plt.grid()
plt.show()

# %%
#Exploring data6 and preparing it as base table

# %%
cols=data6.columns
cols
# Out:
# Index(['SubscriptionID', 'CustomerID', 'ProductID', 'Pattern', 'StartDate',
#        'EndDate', 'NbrNewspapers', 'NbrStart', 'RenewalDate', 'PaymentType',
#        'PaymentStatus', 'PaymentDate', 'FormulaID', 'GrossFormulaPrice',
#        'NetFormulaPrice', 'NetNewspaperPrice', 'ProductDiscount',
#        'FormulaDiscount', 'TotalDiscount', 'TotalPrice', 'TotalCredit'],
#       dtype='object')

# %%
data6=data6.drop('TotalCredit',axis=1)
data6.reset_index(inplace=True)
data6.columns=cols
cols
# Out:
# Index(['SubscriptionID', 'CustomerID', 'ProductID', 'Pattern', 'StartDate',
#        'EndDate', 'NbrNewspapers', 'NbrStart', 'RenewalDate', 'PaymentType',
#        'PaymentStatus', 'PaymentDate', 'FormulaID', 'GrossFormulaPrice',
#        'NetFormulaPrice', 'NetNewspaperPrice', 'ProductDiscount',
#        'FormulaDiscount', 'TotalDiscount', 'TotalPrice', 'TotalCredit'],
#       dtype='object')

# %%
for i in range(4,len(data6.columns)-1):
    data6.iloc[0,i]=data6.iloc[0,i+1]

# %%
for i in range(len(data6)):
    if (data6.iloc[i,7]=='BT'):
        for j in range(len(data6.columns)-3,6,-1):
            data6.iloc[i,j+2]=data6.iloc[i,j]
        data6.iloc[i,7]=np.nan
        data6.iloc[i,8]=np.nan
    
    if (data6.iloc[i,8]=='BT' or data6.iloc[i,8]=='DD'):
        for j in range(len(data6.columns)-2,7,-1):
            data6.iloc[i,j+1]=data6.iloc[i,j]
        data6.iloc[i,8]=np.nan
    
    if (data6.iloc[i,10]=='Not'):
        data6.iloc[i,10]='Not Paid'
        data6.iloc[i,11]=np.nan
    
    x=str(data6.iloc[i,7])
    
    if (x.rfind('/')!=-1):
        data6.iloc[i,8]=data6.iloc[i,7]
        data6.iloc[i,7]=np.nan
    
    x=str(data6.iloc[i,12])
    
    if (x.rfind('/')!=-1):
        data6.iloc[i,12]='99999999'
    
    if(type(data6.loc[i,'NetNewspaperPrice'])!=float):
        x=str(data6.loc[i,'NetNewspaperPrice'])
        if((data6.loc[i,'NetNewspaperPrice'].count('.')>1)|(x.rfind('-')!=-1)):
            data6.loc[i,'NetNewspaperPrice']=np.nan
    
    if(type(data6.loc[i,'FormulaDiscount'])!=float):
        if(data6.loc[i,'FormulaDiscount'].count('.')>1):
            data6.loc[i,'FormulaDiscount']=np.nan
    
    if(type(data6.loc[i,'TotalDiscount'])!=float):
        if(data6.loc[i,'TotalDiscount'].count('.')>1):
            data6.loc[i,'TotalDiscount']=np.nan
    
    if(type(data6.loc[i,'ProductDiscount'])!=float):
        if(data6.loc[i,'ProductDiscount'].count('.')>1):
            data6.loc[i,'ProductDiscount']=np.nan
    
    if(type(data6.loc[i,'TotalCredit'])!=float):
        if(data6.loc[i,'TotalCredit'].count('.')>1):
            data6.loc[i,'TotalCredit']=np.nan
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-bb0a7e681bf1> in <module>()
# ----> 1 for i in range(len(data6)):
#       2     if (data6.iloc[i,7]=='BT'):
#       3         for j in range(len(data6.columns)-3,6,-1):
#       4             data6.iloc[i,j+2]=data6.iloc[i,j]
#       5         data6.iloc[i,7]=np.nan
#
# NameError: name 'data6' is not defined

# %%
x=['NetNewspaperPrice','FormulaDiscount','TotalDiscount','ProductDiscount','TotalCredit']

# %%
for i in x:
    data6[i]=data6[i].astype(float)

# %%
data6=data6.drop(data6.index[15459:15471])

# %%
data6.FormulaID=data6.FormulaID.astype(int)

# %%
data6.RenewalDate=np.where(data6.RenewalDate.isna()==True,'01/01/2099',data6.RenewalDate)
data6.PaymentDate=np.where(data6.PaymentDate.isna()==True,'01/01/2099',data6.PaymentDate)

# %%
x=['StartDate','EndDate','RenewalDate','PaymentDate']

# %%
for i in x:
    data6[i]=pd.to_datetime(data6[i],format='%d/%m/%Y')

# %%
data4.StartDate=pd.to_datetime(data4.StartDate,format='%d/%m/%Y')        
data4.EndDate=pd.to_datetime(data4.EndDate,format='%d/%m/%Y')    
data3.DOB=pd.to_datetime(data3.DOB,format='%d/%m/%Y')

# %%
#Defining base table as "data"

# %%
data=pd.merge(data6,data5,how='left',on='FormulaID')
data=pd.merge(data4,data,how='left',on='SubscriptionID')
data=pd.merge(data,data3,how='left',on='CustomerID')
data=pd.merge(data,data2,how='left',on='SubscriptionID')
data=pd.merge(data,data1,how='left',on=['CustomerID','ProductID'])

# %%
#Removing columns with high correlation
data=data.drop(['FeedbackType','SolutionType','ComplaintDate','ComplaintID','ComplaintType','TotalPrice','NbrNewspapers_y','NbrStart','Amount','CreditSource','ProcessingDate','GrossFormulaPrice','ActionType','Duration','FormulaType','FormulaCode','DeliveryContext','NetFormulaPrice'],axis=1)

# %%
data.NbrNewspapers_x=data.NbrNewspapers_x.astype(int)

# %%
#Defining Churn in reference to Renewal Date, Start Date and End Date
data['Churn']=np.where((data.RenewalDate > data.StartDate_y) & (data.RenewalDate < data.EndDate_y),0,1)

# %%
#Defining Quantiles for treating outliers later

# %%
desc=data.describe().T
desc['1%']=data.quantile(.01)
desc['5%']=data.quantile(.05)
desc['95%']=data.quantile(.95)
desc['99%']=data.quantile(.99)
desc['Q3-Q1']=desc['75%']-desc['25%']
desc['UB']=desc['75%']+(desc['Q3-Q1']*1.5)
desc['LB']=desc['25%']-(desc['Q3-Q1']*1.5)
# SubscriptionID     5.918435e+05 -5.590822e+05  1.808292e+06
# CustomerID         6.113200e+05 -7.478240e+05  1.697456e+06
# ProductID          4.000000e+00 -2.000000e+00  1.400000e+01
# Pattern            0.000000e+00  1.111110e+06  1.111110e+06
# NbrNewspapers_x    2.280000e+02 -2.660000e+02  6.460000e+02
# FormulaID          9.999910e+07 -1.499978e+08  2.499987e+08
# NetNewspaperPrice  1.273410e-01  5.647645e-01  1.074129e+00
# ProductDiscount    0.000000e+00  0.000000e+00  0.000000e+00
# FormulaDiscount    0.000000e+00  0.000000e+00  0.000000e+00
# TotalDiscount      0.000000e+00  0.000000e+00  0.000000e+00
# TotalCredit        0.000000e+00  0.000000e+00  0.000000e+00
# District           4.000000e+00 -5.000000e+00  1.100000e+01
# ZIP                1.090000e+03  9.650000e+02  5.325000e+03
# StreeID            1.990800e+04 -5.976000e+03  7.365600e+04
# Churn              1.000000e+00 -1.500000e+00  2.500000e+00

# %%
#Creating dummy variables and handling missing values

# %%
cols=pd.get_dummies(data['DeliveryClass'],prefix='DeliveryClass')
data=pd.concat([data,cols],axis=1)
data=data.drop('DeliveryClass',axis=1)

# %%
data=data.dropna()
data.reset_index(drop=True,inplace=True)

# %%
data.NetNewspaperPrice=data.NetNewspaperPrice.fillna(data.NetNewspaperPrice.median())

# %%
data.TotalDiscount=data.TotalDiscount.fillna(data.TotalDiscount.mode())

# %%
data.FormulaDiscount=data.FormulaDiscount.fillna(data.FormulaDiscount.mode())

# %%
#Handling Outliers

# %%
data['NbrNewspapers_x']=np.clip(data['NbrNewspapers_x'],desc.loc['NbrNewspapers_x','1%'],desc.loc['NbrNewspapers_x','99%'])
data['NetNewspaperPrice']=np.clip(data['NetNewspaperPrice'],desc.loc['NetNewspaperPrice','1%'],desc.loc['NetNewspaperPrice','99%'])
data['TotalCredit']=data['TotalCredit'].clip_lower(desc.loc['TotalCredit','1%'])

# %%
lecr=LabelEncoder()
data['Gender']=lecr.fit_transform(data['Gender'])
data['PaymentStatus']=lecr.fit_transform(data['PaymentStatus'])
data['PaymentType']=lecr.fit_transform(data['PaymentType'])

# %%
cols=pd.get_dummies(data['District'],prefix='District')
cols=cols.drop(cols.columns[0],axis=1)

# %%
data=pd.concat([data,cols],axis=1)
data=data.drop('District',axis=1)

# %%
cols=pd.get_dummies(data['DeliveryType'],prefix='DeliveryType')
cols=cols.drop(cols.columns[0],axis=1)

# %%
data=pd.concat([data,cols],axis=1)
data=data.drop('DeliveryType',axis=1)

# %%
data=data.drop_duplicates()
data=data.reset_index(drop=True)

# %%
for i in range(len(data)):
    data.loc[i,'DOB']=pd.datetime.toordinal(data.loc[i,'DOB'])
    data.loc[i,'RenewalDate']=pd.datetime.toordinal(data.loc[i,'RenewalDate'])
    data.loc[i,'PaymentDate']=pd.datetime.toordinal((data.loc[i,'PaymentDate']))
    data.loc[i,'StartDate_x']=pd.datetime.toordinal((data.loc[i,'StartDate_x']))
    data.loc[i,'EndDate_x']=pd.datetime.toordinal((data.loc[i,'EndDate_x']))
    data.loc[i,'StartDate_y']=pd.datetime.toordinal((data.loc[i,'StartDate_y']))
    data.loc[i,'EndDate_y']=pd.datetime.toordinal((data.loc[i,'EndDate_y']))

# %%
y=data['Churn']
data.drop('Churn',axis=1,inplace=True)
data.index=data.CustomerID

# %%
data.drop(columns=["CustomerID","SubscriptionID"],axis=1,inplace=True)

# %%
plt.figure(figsize=(15,10))
sns.heatmap(data.corr())
plt.show()

# %%
data.drop_duplicates()
# Out:
#             StartDate_x  EndDate_x  ProductID    Pattern  StartDate_y  \
# CustomerID
# 1150046          733815     733816        8.0  1111110.0       733786
# 1150046          733787     733814        8.0  1111110.0       733786
# 1150046          733817     733843        8.0  1111110.0       733786
# 1150046          733786     733786        8.0  1111110.0       733786
# 89085            733042     733406        8.0  1111110.0       733042
# 89085            732678     733041        8.0  1111110.0       732678
# 89087            733042     733242        8.0  1111110.0       733042
# 89087            733251     733406        8.0  1111110.0       733042
# 89087            733243     733250        8.0  1111110.0       733042
# 89087            732678     732772        8.0  1111110.0       732678
# 89087            732781     732886        8.0  1111110.0       732678
# 89087            732893     733041        8.0  1111110.0       732678
# 89087            732773     732780        8.0  1111110.0       732678
# 89087            732887     732892        8.0  1111110.0       732678
# 325943           733816     734180        2.0  1111110.0       733816
# 191542           733829     733829        8.0  1111110.0       733816
# 191542           733816     733827        8.0  1111110.0       733816
# 191542           733828     733828        8.0  1111110.0       733816
# 191542           733833     734011        8.0  1111110.0       733816
# 191542           734026     734196        8.0  1111110.0       733816
# 191542           733830     733832        8.0  1111110.0       733816
# 191542           734012     734025        8.0  1111110.0       733816
# 83885            733816     734006        8.0  1111110.0       733816
# 83885            734007     734019        8.0  1111110.0       733816
# 83885            734020     734180        8.0  1111110.0       733816
# 809659           733816     734180        3.0  1111110.0       733816
# 89154            733170     733534        8.0  1111110.0       733170
# 89154            732804     733169        8.0  1111110.0       732804
# 89154            732439     732803        8.0  1111110.0       732439
# 1150113          733788     733815        8.0  1111110.0       733787
# ...                 ...        ...        ...        ...          ...
# 1149106          733785     733785        8.0  1111110.0       733785
# 1149106          733922     733935        8.0  1111110.0       733785
# 143748           733798     733826        8.0  1111110.0       733798
# 1149771          733785     733813        3.0  1111110.0       733785
# 89035            733042     733406        8.0  1111110.0       733042
# 89035            732678     733041        8.0  1111110.0       732678
# 661185           733815     733927        2.0  1111110.0       733815
# 661185           733941     733976        2.0  1111110.0       733815
# 661185           733992     734207        2.0  1111110.0       733815
# 661185           733977     733991        2.0  1111110.0       733815
# 661185           733928     733940        2.0  1111110.0       733815
# 705154           733815     734014        2.0  1111110.0       733815
# 705154           734024     734189        2.0  1111110.0       733815
# 705154           734015     734023        2.0  1111110.0       733815
# 477393           734016     734139        1.0  1111110.0       733815
# 477393           734146     734185        1.0  1111110.0       733815
# 477393           733815     733866        1.0  1111110.0       733815
# 477393           733873     733971        1.0  1111110.0       733815
# 477393           733984     733997        1.0  1111110.0       733815
# 477393           733998     734015        1.0  1111110.0       733815
# 477393           734140     734145        1.0  1111110.0       733815
# 477393           733972     733983        1.0  1111110.0       733815
# 477393           733867     733872        1.0  1111110.0       733815
# 249391           733815     734179        8.0  1111110.0       733815
# 652668           733815     734179        2.0  1111110.0       733815
# 729149           733815     734179        2.0  1111110.0       733815
# 788976               0           0           1           0           0
#
#             District_8  DeliveryType_DR  DeliveryType_MD
# CustomerID
# 1150046              0                0                1
# 1150046              0                0                1
# 1150046              0                0                1
# 1150046              0                0                1
# 89085                0                0                1
# 89085                0                0                1
# 89087                0                0                1
# 89087                0                0                1
# 89087                0                1                0
# 89087                0                0                1
# 89087                0                0                1
# 89087                0                0                1
# 89087                0                1                0
# 89087                0                1                0
# 325943               0                0                1
# 191542               0                0                1
# 191542               0                0                1
# 191542               0                0                0
# 191542               0                0                1
# 191542               0                0                1
# 191542               0                0                1
# 191542               0                0                0
# 83885                0                0                1
# 83885                0                1                0
# 83885                0                0                1
# 809659               0                0                1
# 89154                0                0                1
# 89154                0                0                1
# 89154                0                0                1
# 1150113              0                0                1
# ...                ...              ...              ...
# 1149106              0                0                1
# 1149106              0                0                0
# 143748               0                0                1
# 1149771              0                0                1
# 89035                0                0                1
# 89035                0                0                1
# 661185               0                0                1
# 661185               0                0                1
# 661185               0                0                1
# 661185               0                0                0
# 661185               0                0                0
# 705154               0                0                1
# 705154               0                0                1
# 705154               0                0                0
# 477393               0                0                1
# 477393               0                0                1
# 477393               0                0                1
# 477393               0                0                1
# 477393               0                0                1
# 477393               0                1                0
# 477393               0                1                0
# 477393               0                1                0
# 477393               0                0                0
# 249391               0                0                1
# 652668               0                0                1
# 729149               0                0                1
# 799724               0                0                1
# 799724               0                0                1
# 788976               0                0                1
# 788976               0                0                1
#
# [21649 rows x 32 columns]

# %%
#Modeling

# %%
x_train,x_test,y_train,y_test=train_test_split(data,y,test_size=0.2,random_state=0)

# %%
names=[
    "Nearest Neighbors", 
    "Decision Tree",
    "Random Forest", 
    "AdaBoost",
    "Neural Net",
    "Naive Bayes", 
    "Linear Discriminant Analysis",
    "Quadratic Discriminant Analysis",
    "Logistic Regression",
    "XGBoost"
    ]

classifiers=[
    KNeighborsClassifier(),
    DecisionTreeClassifier(max_depth=5),
    RandomForestClassifier(max_depth=5, n_estimators=500),
    AdaBoostClassifier(),
    MLPClassifier(alpha=1, max_iter=1000),
    GaussianNB(),
    LinearDiscriminantAnalysis(),
    QuadraticDiscriminantAnalysis(),
    LogisticRegression(),
    xgboost.XGBClassifier()
    ]

# %%
for i,j in zip(names,classifiers):
    j.fit(x_train,y_train)
    
    score = j.score(x_test,y_test)
    ypred=j.predict(x_test)    
    cv_acc=cross_val_score(estimator=j,X=x_train,y=y_train,cv=5)
    cm=confusion_matrix(y_test,ypred)
    cv_acc=cv_acc.mean()
    acc=accuracy_score(y_test,ypred)
    f1=f1_score(y_test,ypred,average='binary')
    auc = roc_auc_score(y_test,ypred)
    aps=average_precision_score(y_test,ypred)   
    
    print("+"*103)
    print("\n Classifier is \n" + str(i))
    print("\n Score \n" + str(score*100) + "%")
    print('\n Confusion Matrix \n',cm)
    print('\n Cross Validation Score \n',cv_acc)
    print('\n Testing Accuracy \n',acc)
    print('\n F1 Score \n',f1)
    print('\n AUC \n',auc)
    print('\n Average Precision Score \n',aps)
    print("\n",j.get_params,"\n")
    
    if i=="XGBoost":
        feature_importances=pd.DataFrame(j.feature_importances_,index = x_train.columns,columns=['importance']).sort_values('importance',ascending=False)
        print(feature_importances)
# Out:
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#
#  Classifier is
# Nearest Neighbors
#
#  Score
# 97.62124711316396%
#
#  Confusion Matrix
#  [[3001   21]
#  [  82 1226]]
#
#  Cross Validation Score
#  0.9755183967231286
#
#  Testing Accuracy
#  0.9762124711316397
#
#  F1 Score
#  0.9596868884540117
#
#  AUC
#  0.9651799140654569
#
#  Average Precision Score
#  0.9404618406392148
#
#  <bound method BaseEstimator.get_params of KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#            metric_params=None, n_jobs=1, n_neighbors=5, p=2,
#            weights='uniform')>
#
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#
#  Classifier is
# Decision Tree
#
#  Score
# 97.50577367205543%
#
#  Confusion Matrix
#  [[3004   18]
#  [  90 1218]]
#
#  Cross Validation Score
#  0.9757492435706002
#
#  Testing Accuracy
#  0.9750577367205543
#
#  F1 Score
#  0.9575471698113207
#
#  AUC
#  0.9626181701163941
#
#  Average Precision Score
#  0.9384168217866407
#
#  <bound method BaseEstimator.get_params of DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=5,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=None,
#             splitter='best')>
#
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#
#  Classifier is
# Random Forest
#
#  Score
# 97.11316397228637%
#
#  Confusion Matrix
#  [[3022    0]
#  [ 125 1183]]
#
#  Cross Validation Score
#  0.9715921163284047
#
#  Testing Accuracy
#  0.9711316397228638
#
#  F1 Score
#  0.9498193496587716
#
#  AUC
#  0.952217125382263
#
#  Average Precision Score
#  0.9333026110416622
#
#  <bound method BaseEstimator.get_params of RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=5, max_features='auto', max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, n_estimators=500, n_jobs=1,
#             oob_score=False, random_state=None, verbose=0,
#             warm_start=False)>
#
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#
#  Classifier is
# AdaBoost
#
#  Score
# 97.71362586605082%
#
#  Confusion Matrix
#  [[2998   24]
#  [  75 1233]]
#
#  Cross Validation Score
#  0.9765576910380205
#
#  Testing Accuracy
#  0.9771362586605081
#
#  F1 Score
#  0.9614035087719298
#
#  AUC
#  0.9673593950175775
#
#  Average Precision Score
#  0.941983274492134
#
#  <bound method BaseEstimator.get_params of AdaBoostClassifier(algorithm='SAMME.R', base_estimator=None,
#           learning_rate=1.0, n_estimators=50, random_state=None)>
#
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#
#  Classifier is
# Neural Net
#
#  Score
# 95.81986143187066%
#
#  Confusion Matrix
#  [[3013    9]
#  [ 172 1136]]
#
#  Cross Validation Score
#  0.9503419187597826
#
#  Testing Accuracy
#  0.9581986143187067
#
#  F1 Score
#  0.9262128006522625
#
#  AUC
#  0.9327616844465763
#
#  Average Precision Score
#  0.9013977432199929
#
#  <bound method BaseEstimator.get_params of MLPClassifier(activation='relu', alpha=1, batch_size='auto', beta_1=0.9,
#        beta_2=0.999, early_stopping=False, epsilon=1e-08,
#        hidden_layer_sizes=(100,), learning_rate='constant',
#        learning_rate_init=0.001, max_iter=1000, momentum=0.9,
#        nesterovs_momentum=True, power_t=0.5, random_state=None,
#        shuffle=True, solver='adam', tol=0.0001, validation_fraction=0.1,
#        verbose=False, warm_start=False)>
#
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#
#  Classifier is
# Naive Bayes
#
#  Score
# 95.61200923787528%
#
#  Confusion Matrix
#  [[2952   70]
#  [ 120 1188]]
#
#  Cross Validation Score
#  0.9588315508253199
#
#  Testing Accuracy
#  0.9561200923787528
#
#  F1 Score
#  0.9259547934528449
#
#  AUC
#  0.9425467064159467
#
#  Average Precision Score
#  0.8854315704701261
#
#  <bound method BaseEstimator.get_params of GaussianNB(priors=None)>
#
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#
#  Classifier is
# Linear Discriminant Analysis
#
#  Score
# 97.09006928406467%
#
#  Confusion Matrix
#  [[3021    1]
#  [ 125 1183]]
#
#  Cross Validation Score
#  0.9713611527737299
#
#  Testing Accuracy
#  0.9709006928406466
#
#  F1 Score
#  0.949438202247191
#
#  AUC
#  0.9520516720401054
#
#  Average Precision Score
#  0.9325387307623003
#
#  <bound method BaseEstimator.get_params of LinearDiscriminantAnalysis(n_components=None, priors=None, shrinkage=None,
#               solver='svd', store_covariance=False, tol=0.0001)>
#
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#
#  Classifier is
# Quadratic Discriminant Analysis
#
#  Score
# 96.28175519630486%
#
#  Confusion Matrix
#  [[2945   77]
#  [  84 1224]]
#
#  Cross Validation Score
#  0.962411494259006
#
#  Testing Accuracy
#  0.9628175519630485
#
#  F1 Score
#  0.9382905327711767
#
#  AUC
#  0.9551500009107524
#
#  Average Precision Score
#  0.8997949996072686
#
#  <bound method BaseEstimator.get_params of QuadraticDiscriminantAnalysis(priors=None, reg_param=0.0,
#                store_covariance=False, store_covariances=None, tol=0.0001)>
#
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#
#  Classifier is
# Logistic Regression
#
#  Score
# 96.85912240184757%
#
#  Confusion Matrix
#  [[3010   12]
#  [ 124 1184]]
#
#  Cross Validation Score
#  0.9696866544979956
#
#  Testing Accuracy
#  0.9685912240184757
#
#  F1 Score
#  0.9456869009584664
#
#  AUC
#  0.9506139482733148
#
#  Average Precision Score
#  0.9247539281791644
#
#  <bound method BaseEstimator.get_params of LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='ovr', n_jobs=1,
#           penalty='l2', random_state=None, solver='liblinear', tol=0.0001,
#           verbose=0, warm_start=False)>
#
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#
#  Classifier is
# XGBoost
#
#  Score
# 97.82909930715935%
#
#  Confusion Matrix
#  [[3001   21]
#  [  73 1235]]
#
#  Cross Validation Score
#  0.9782900427415122
#
#  Testing Accuracy
#  0.9782909930715935
#
#  F1 Score
#  0.9633385335413416
#
#  AUC
#  0.9686202810379339
#
#  Average Precision Score
#  0.9452621152532861
#
#  <bound method XGBModel.get_params of XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#        colsample_bytree=1, gamma=0, learning_rate=0.1, max_delta_step=0,
#        max_depth=3, min_child_weight=1, missing=None, n_estimators=100,
#        n_jobs=1, nthread=None, objective='binary:logistic', random_state=0,
#        reg_alpha=0, reg_lambda=1, scale_pos_weight=1, seed=None,
#        silent=True, subsample=1)>
#
#                    importance
# RenewalDate          0.215264
# FormulaID            0.127202
# EndDate_y            0.105675
# NbrNewspapers_x      0.093933
# NetNewspaperPrice    0.088063
# DOB                  0.054795
# PaymentStatus        0.052838
# StreeID              0.046967
# PaymentDate          0.043053
# ZIP                  0.029354
# StartDate_y          0.029354
# EndDate_x            0.027397
# FormulaDiscount      0.025440
# PaymentType          0.023483
# TotalDiscount        0.021526
# StartDate_x          0.005871
# TotalCredit          0.003914
# ProductID            0.003914
# Gender               0.001957
# ProductDiscount      0.000000
# Pattern              0.000000
# DeliveryClass_ABN    0.000000
# DeliveryClass_NOR    0.000000
# District_2           0.000000
# District_3           0.000000
# District_4           0.000000
# District_5           0.000000
# District_6           0.000000
# District_7           0.000000
# District_8           0.000000
# DeliveryType_DR      0.000000
# DeliveryType_MD      0.000000

# %%
#As observed, here XGBoost yields best accuracy. Accordingly, we have the corresponding feature importances above.
#According to the mentioned importance, we can reduce the number of features to make the model better. Here, we remove features that have no or very little impact with regard to the model.

# %%
data=data[["RenewalDate","FormulaID","EndDate_y","NbrNewspapers_x","NetNewspaperPrice"]]

# %%
#Re-Modeling
x_train,x_test,y_train,y_test=train_test_split(data,y,test_size=0.2,random_state=0)

# %%
model=xgboost.XGBClassifier()
model.fit(x_train,y_train)
score = model.score(x_test,y_test)
feature_importances=pd.DataFrame(model.feature_importances_,index = x_train.columns,columns=['importance']).sort_values('importance',ascending=False)
print("\n Score \n" + str(score*100) + "%")
print(feature_importances)
# Out:
#  Score
# 98.10623556581987%
#                    importance
# RenewalDate          0.338710
# FormulaID            0.215726
# EndDate_y            0.183468
# NbrNewspapers_x      0.131048
# NetNewspaperPrice    0.131048

# %%
#Apart from features highlighted above, we also observe that:
#1. Complaints for Product with ID 8 are maximum.
#2. Complaint Type 1 are maximum.
#3. Maximum customers are from District 5, followed by District 1.
#4. There are more Male customers.
